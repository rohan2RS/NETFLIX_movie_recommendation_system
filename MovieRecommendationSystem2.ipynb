# %% [markdown]
# <a href="https://colab.research.google.com/github/rohan2RS/NETFLIX_movie_recommendation_system/blob/main/MovieRecommendationSystem2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('/content/sample_data/netflix_titles.csv')
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # Task
# Create a hybrid movie recommendation system using the dataset at "/content/sample_data/netflix_titles.csv".

# %% [markdown]
# ## Data loading and exploration
#
# ### Subtask:
# Load the data into a pandas DataFrame and perform initial exploration to understand the structure and content of the data.

# %% [markdown]
# **Reasoning**:
# Display the first and last 5 rows, show column information and data types, generate descriptive statistics, and check for missing values to explore the data.

# %%
display(data.head())
display(data.tail())
data.info()
display(data.describe())
display(data.isnull().sum())
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ## Data preprocessing
#
# ### Subtask:
# Handle missing values, convert data types, and perform any necessary feature engineering (e.g., extracting relevant information from text fields).

# %% [markdown]
# **Reasoning**:
# Handle missing values in specified columns, convert 'date_added' to datetime and extract year and month, and process the 'duration' column based on the 'type'.

# %%
# Example usage:
movie_title = 'Ganglands'  # Replace with a movie title from the dataset
recommendations = generate_recommendations(movie_title)

if isinstance(recommendations, str):
    print(recommendations)
else:
    print(f"Recommendations for '{movie_title}':")
    display(recommendations)
# Out:
# Recommendations for 'Ganglands':
# 2668                               Earth and Blood
# 3976                        The Eagle of El-Se'eed
# 3789                                Killer Ratings
# 7017    How to Live Mortgage Free with Sarah Beeny
# 5822                                       Cocaine
# 4399                                       Warrior
# 5210                        The Day I Met El Chapo
# 3297                                Paradise Beach
# 310            Cocaine Cowboys: The Kings of Miami
# 3425                                   Street Flow
# Name: title, dtype: object

# %%
# 1. Fill missing values
data['director'].fillna('Unknown', inplace=True)
data['cast'].fillna('Unknown', inplace=True)
data['country'].fillna('Unknown', inplace=True)
data['date_added'].fillna('Not Available', inplace=True)
data['rating'].fillna('Unknown', inplace=True)

# 2. Fill missing values in 'duration' based on 'type'
data.loc[(data['type'] == 'Movie') & (data['duration'].isnull()), 'duration'] = 'Unknown Duration'
data.loc[(data['type'] == 'TV Show') & (data['duration'].isnull()), 'duration'] = 'Unknown Seasons'

# 3. Convert 'date_added' to datetime object, handling 'Not Available'
data['date_added'] = pd.to_datetime(data['date_added'], errors='coerce')

# 4. Extract year and month from 'date_added'
data['year_added'] = data['date_added'].dt.year
data['month_added'] = data['date_added'].dt.month

# Fill NaN values created by coercion in 'date_added', 'year_added', 'month_added'
data['date_added'].fillna(pd.Timestamp('1900-01-01'), inplace=True) # Using a placeholder date
data['year_added'].fillna(1900, inplace=True)
data['month_added'].fillna(1, inplace=True)

# Convert year_added and month_added to integer type after filling NaNs
data['year_added'] = data['year_added'].astype(int)
data['month_added'] = data['month_added'].astype(int)


# 5. Process 'duration'
# For Movies
movie_duration = data[data['type'] == 'Movie'].copy()
movie_duration['duration'] = movie_duration['duration'].astype(str).str.replace(' min', '', regex=False)
movie_duration['duration'] = pd.to_numeric(movie_duration['duration'], errors='coerce')
movie_duration['duration'].fillna(movie_duration['duration'].median(), inplace=True) # Fill with median

# For TV Shows
tv_show_duration = data[data['type'] == 'TV Show'].copy()
tv_show_duration['duration'] = tv_show_duration['duration'].astype(str).str.replace(' Seasons', '', regex=False).str.replace(' Season', '', regex=False)
tv_show_duration['duration'] = pd.to_numeric(tv_show_duration['duration'], errors='coerce')
tv_show_duration['duration'].fillna(tv_show_duration['duration'].median(), inplace=True) # Fill with median


# Update the original dataframe with processed duration data
data.loc[data['type'] == 'Movie', 'duration'] = movie_duration['duration']
data.loc[data['type'] == 'TV Show', 'duration'] = tv_show_duration['duration']

# Convert duration to integer type after filling NaNs
data['duration'] = data['duration'].astype(int)

display(data.head())
display(data.isnull().sum())
display(data.info())
# Out:
# /tmp/ipython-input-1214084273.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['director'].fillna('Unknown', inplace=True)
# /tmp/ipython-input-1214084273.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ## Content-based filtering
#
# ### Subtask:
# Implement content-based filtering by using features like genre, director, cast, and description to recommend similar movies. This might involve techniques like TF-IDF vectorization and cosine similarity.

# %% [markdown]
# **Reasoning**:
# Combine the relevant text features for content-based filtering into a single column and display the first few rows to verify the result.

# %%
data['combined_features'] = data['director'] + ' ' + data['cast'] + ' ' + data['listed_in'] + ' ' + data['description']
display(data[['title', 'combined_features']].head())
# Out:
#                    title                                  combined_features
# 0   Dick Johnson Is Dead  Kirsten Johnson Unknown Documentaries As her f...
# 1          Blood & Water  Unknown Ama Qamata, Khosi Ngema, Gail Mabalane...
# 2              Ganglands  Julien Leclercq Sami Bouajila, Tracy Gotoas, S...
# 3  Jailbirds New Orleans  Unknown Unknown Docuseries, Reality TV Feuds, ...
# 4           Kota Factory  Unknown Mayur More, Jitendra Kumar, Ranjan Raj...

# %% [markdown]
# **Reasoning**:
# Initialize and fit a TF-IDF Vectorizer on the combined text data and then compute the cosine similarity matrix.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(data['combined_features'])

cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
display(cosine_sim.shape)
# Out:
# (8807, 8807)

# %% [markdown]
# ## Collaborative filtering
#
# ### Subtask:
# Implement collaborative filtering techniques (e.g., matrix factorization or neighborhood-based methods) to find users with similar preferences and recommend movies they liked.

# %% [markdown]
# **Reasoning**:
# I need to check if there is explicit user-item interaction data or implicit feedback in the dataset to determine the appropriate collaborative filtering technique.

# %%
display(data.columns)
# Check if there are columns related to user ID, item ID, or ratings/interactions.
user_interaction_columns = ['user_id', 'item_id', 'rating', 'views'] # Example column names
found_interaction_columns = [col for col in user_interaction_columns if col in data.columns]
print(f"Columns related to user interaction found: {found_interaction_columns}")
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'year_added', 'month_added', 'combined_features'],
#       dtype='object')
# Columns related to user interaction found: ['rating']

# %% [markdown]
# ## Hybrid filtering
#
# ### Subtask:
# Combine the results from content-based and collaborative filtering to create a hybrid recommendation system. This could involve weighted averaging, stacking, or other combination techniques.

# %% [markdown]
# ## Hybrid filtering
#
# ### Subtask:
# Combine the results from content-based and collaborative filtering to create a hybrid recommendation system. This could involve weighted averaging, stacking, or other combination techniques.

# %% [markdown]
# **Reasoning**:
# Define the function `get_recommendations` to provide content-based recommendations based on the cosine similarity matrix.

# %%
def get_recommendations(title, cosine_sim=cosine_sim):
    """
    Gets content-based recommendations for a given movie title.

    Args:
        title (str): The title of the movie for which to get recommendations.
        cosine_sim (numpy.ndarray): The cosine similarity matrix.

    Returns:
        pandas.Series: A Series of the top 10 most similar movie titles.
    """
    # Get the index of the movie that matches the title
    indices = pd.Series(data.index, index=data['title']).drop_duplicates()
    if title not in indices:
        return "Movie title not found in the dataset."

    idx = indices[title]

    # Get the pairwise similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies (excluding the input movie itself)
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the titles of the top 10 most similar movies
    return data['title'].iloc[movie_indices]

# Example usage:
# print(get_recommendations('Kota Factory'))

# %% [markdown]
# ## Model evaluation
#
# ### Subtask:
# Evaluate the performance of the recommendation system using appropriate metrics (e.g., precision, recall, RMSE).

# %% [markdown]
# **Reasoning**:
# Acknowledge the limitations of the dataset and the implemented content-based approach for quantitative evaluation using standard metrics.

# %%
print("Due to the nature of the dataset, which lacks explicit user interaction data (like individual user ratings or viewing history), traditional collaborative filtering metrics such as RMSE, Precision, and Recall, which require ground truth user ratings or interactions, cannot be directly applied to evaluate the performance of the implemented content-based recommendation system.")
print("Evaluating a content-based recommendation system without explicit user feedback is inherently challenging.")
print("A meaningful assessment would typically require a qualitative evaluation (e.g., manually checking the relevance of recommendations for a few items) or conducting user studies to gather feedback, but these methods are outside the scope of this automated process.")
print("Therefore, a rigorous quantitative evaluation using standard recommendation system metrics is not feasible with the current data and the content-based approach alone.")
# Out:
# Due to the nature of the dataset, which lacks explicit user interaction data (like individual user ratings or viewing history), traditional collaborative filtering metrics such as RMSE, Precision, and Recall, which require ground truth user ratings or interactions, cannot be directly applied to evaluate the performance of the implemented content-based recommendation system.
# Evaluating a content-based recommendation system without explicit user feedback is inherently challenging.
# A meaningful assessment would typically require a qualitative evaluation (e.g., manually checking the relevance of recommendations for a few items) or conducting user studies to gather feedback, but these methods are outside the scope of this automated process.
# Therefore, a rigorous quantitative evaluation using standard recommendation system metrics is not feasible with the current data and the content-based approach alone.

# %% [markdown]
# ## Recommendation generation
#
# ### Subtask:
# Develop a function or module to generate recommendations for a given user or movie.

# %% [markdown]
# **Reasoning**:
# Define the `generate_recommendations` function as per the instructions, which will call the previously defined `get_recommendations` function.

# %%
def generate_recommendations(movie_title):
    """
    Generates content-based recommendations for a given movie title.

    Args:
        movie_title (str): The title of the movie for which to get recommendations.

    Returns:
        pandas.Series or str: A Series of the top 10 most similar movie titles
                                or a string message if the movie is not found.
    """
    return get_recommendations(movie_title)

# Example usage:
# print(generate_recommendations('Zodiac'))

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The dataset contains 8807 entries and 12 columns, with several columns having missing values (director, cast, country, date\_added, rating, and duration).
# *   Missing values in various columns were handled by filling them with placeholder values like 'Unknown', 'Not Available', or median values based on content type for duration.
# *   New features `year_added` and `month_added` were successfully extracted from the `date_added` column.
# *   Content-based filtering was implemented by combining text features and computing a cosine similarity matrix using TF-IDF vectorization. The shape of the cosine similarity matrix is (8807, 8807).
# *   Collaborative filtering could not be implemented due to the absence of explicit user interaction data (user IDs, individual ratings/views) in the dataset.
# *   Due to the lack of user interaction data, traditional recommendation system evaluation metrics like RMSE, Precision, and Recall were not applicable.
# *   A function `generate_recommendations` was created to provide content-based recommendations using the pre-computed cosine similarity matrix.
#
# ### Insights or Next Steps
#
# *   The current system is solely content-based due to data limitations. To build a truly hybrid system, acquiring or simulating user interaction data would be necessary.
# *   Evaluating the content-based recommendations would require qualitative methods or user studies to assess the relevance of the suggested titles.

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ⠙
# ...
#
# ⠹⠸⠼⠴⠦
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.229.165.4:8501
#
# ⠧⠇⠏⠋⠙⠹⠸your url is: https://stupid-rabbits-play.loca.lt
# /content/app.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['director'].fillna('Unknown', inplace=True)
# /content/app.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# # Task
# Create a Streamlit application for a hybrid movie recommendation system using the dataset "/content/sample_data/netflix_titles.csv".

# %% [markdown]
# ## Install streamlit
#
# ### Subtask:
# Install the Streamlit library in your environment.

# %% [markdown]
# **Reasoning**:
# Install the streamlit library using pip.

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 52.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 90.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Create a streamlit app file
#
# ### Subtask:
# Create a new Python file that will contain the code for your Streamlit application.

# %% [markdown]
# **Reasoning**:
# Create an empty file named `app.py`.

# %%
# !touch app.py

# %% [markdown]
# **Reasoning**:
# Verify that the file `app.py` was created successfully.

# %%
# !ls
# Out:
# app.py	sample_data

# %% [markdown]
# ## Import libraries and load data
#
# ### Subtask:
# Import necessary libraries (pandas, sklearn, streamlit) and load the Netflix data. Reuse the data loading and preprocessing steps from the notebook.

# %% [markdown]
# **Reasoning**:
# Import necessary libraries, load the data, and apply the preprocessing steps from the notebook, ensuring inplace arguments are handled correctly and duration is processed accurately.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import streamlit as st

# Load the dataset
data = pd.read_csv('/content/sample_data/netflix_titles.csv')

# Preprocessing steps from the notebook
# 1. Fill missing values
data['director'] = data['director'].fillna('Unknown')
data['cast'] = data['cast'].fillna('Unknown')
data['country'] = data['country'].fillna('Unknown')
data['date_added'] = data['date_added'].fillna('Not Available')
data['rating'] = data['rating'].fillna('Unknown')

# 2. Fill missing values in 'duration' based on 'type'
data.loc[(data['type'] == 'Movie') & (data['duration'].isnull()), 'duration'] = 'Unknown Duration'
data.loc[(data['type'] == 'TV Show') & (data['duration'].isnull()), 'duration'] = 'Unknown Seasons'

# 3. Convert 'date_added' to datetime object, handling 'Not Available'
data['date_added'] = pd.to_datetime(data['date_added'], errors='coerce')

# 4. Extract year and month from 'date_added'
data['year_added'] = data['date_added'].dt.year
data['month_added'] = data['date_added'].dt.month

# Fill NaN values created by coercion in 'date_added', 'year_added', 'month_added'
data['date_added'] = data['date_added'].fillna(pd.Timestamp('1900-01-01')) # Using a placeholder date
data['year_added'] = data['year_added'].fillna(1900).astype(int)
data['month_added'] = data['month_added'].fillna(1).astype(int)

# 5. Process 'duration'
# For Movies
movie_duration_mask = data['type'] == 'Movie'
data.loc[movie_duration_mask, 'duration'] = data.loc[movie_duration_mask, 'duration'].astype(str).str.replace(' min', '', regex=False)
data.loc[movie_duration_mask, 'duration'] = pd.to_numeric(data.loc[movie_duration_mask, 'duration'], errors='coerce')
movie_median_duration = data.loc[movie_duration_mask, 'duration'].median()
data.loc[movie_duration_mask, 'duration'] = data.loc[movie_duration_mask, 'duration'].fillna(movie_median_duration)

# For TV Shows
tv_show_duration_mask = data['type'] == 'TV Show'
data.loc[tv_show_duration_mask, 'duration'] = data.loc[tv_show_duration_mask, 'duration'].astype(str).str.replace(' Seasons', '', regex=False).str.replace(' Season', '', regex=False)
data.loc[tv_show_duration_mask, 'duration'] = pd.to_numeric(data.loc[tv_show_duration_mask, 'duration'], errors='coerce')
tv_show_median_duration = data.loc[tv_show_duration_mask, 'duration'].median()
data.loc[tv_show_duration_mask, 'duration'] = data.loc[tv_show_duration_mask, 'duration'].fillna(tv_show_median_duration)

# Convert duration to integer type after filling NaNs
data['duration'] = data['duration'].astype(int)

# Combine features for content-based filtering
data['combined_features'] = data['director'] + ' ' + data['cast'] + ' ' + data['listed_in'] + ' ' + data['description']

# Display the first few rows and check for null values
display(data.head())
display(data.isnull().sum())
# Out:
# /tmp/ipython-input-2243047444.py:39: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.loc[movie_duration_mask, 'duration'] = data.loc[movie_duration_mask, 'duration'].fillna(movie_median_duration)
# /tmp/ipython-input-2243047444.py:46: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.loc[tv_show_duration_mask, 'duration'] = data.loc[tv_show_duration_mask, 'duration'].fillna(tv_show_median_duration)
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# ...

# %% [markdown]
# **Reasoning**:
# The data loading and preprocessing steps are complete and verified. The next step is to implement the content-based filtering logic by creating the TF-IDF vectorizer and computing the cosine similarity matrix.

# %%
# Create TF-IDF vectorizer and fit on combined features
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(data['combined_features'])

# Compute cosine similarity matrix
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Display the shape of the cosine similarity matrix
display(cosine_sim.shape)
# Out:
# (8807, 8807)

# %% [markdown]
# ## Implement recommendation logic
#
# ### Subtask:
# Copy the relevant code for the content-based filtering, including the TF-IDF vectorizer, cosine similarity calculation, and the `get_recommendations` function, into the Streamlit app file.

# %% [markdown]
# **Reasoning**:
# Copy the content-based filtering code into the Streamlit app file.

# %%
# %%writefile app.py
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import streamlit as st

# Load the data
data = pd.read_csv('/content/sample_data/netflix_titles.csv')

# Data preprocessing
data['director'].fillna('Unknown', inplace=True)
data['cast'].fillna('Unknown', inplace=True)
data['country'].fillna('Unknown', inplace=True)
data['date_added'].fillna('Not Available', inplace=True)
data['rating'].fillna('Unknown', inplace=True)

data.loc[(data['type'] == 'Movie') & (data['duration'].isnull()), 'duration'] = 'Unknown Duration'
data.loc[(data['type'] == 'TV Show') & (data['duration'].isnull()), 'duration'] = 'Unknown Seasons'

data['date_added'] = pd.to_datetime(data['date_added'], errors='coerce')
data['year_added'] = data['date_added'].dt.year
data['month_added'] = data['date_added'].dt.month

data['date_added'].fillna(pd.Timestamp('1900-01-01'), inplace=True)
data['year_added'].fillna(1900, inplace=True)
data['month_added'].fillna(1, inplace=True)

data['year_added'] = data['year_added'].astype(int)
data['month_added'] = data['month_added'].astype(int)

movie_duration = data[data['type'] == 'Movie'].copy()
movie_duration['duration'] = movie_duration['duration'].astype(str).str.replace(' min', '', regex=False)
movie_duration['duration'] = pd.to_numeric(movie_duration['duration'], errors='coerce')
movie_duration['duration'].fillna(movie_duration['duration'].median(), inplace=True)

tv_show_duration = data[data['type'] == 'TV Show'].copy()
tv_show_duration['duration'] = tv_show_duration['duration'].astype(str).str.replace(' Seasons', '', regex=False).str.replace(' Season', '', regex=False)
tv_show_duration['duration'] = pd.to_numeric(tv_show_duration['duration'], errors='coerce')
tv_show_duration['duration'].fillna(tv_show_duration['duration'].median(), inplace=True)

data.loc[data['type'] == 'Movie', 'duration'] = movie_duration['duration']
data.loc[data['type'] == 'TV Show', 'duration'] = tv_show_duration['duration']
data['duration'] = data['duration'].astype(int)

# Content-based filtering code
data['combined_features'] = data['director'] + ' ' + data['cast'] + ' ' + data['listed_in'] + ' ' + data['description']

tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(data['combined_features'])

cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

def get_recommendations(title, cosine_sim=cosine_sim):
    """
    Gets content-based recommendations for a given movie title.

    Args:
        title (str): The title of the movie for which to get recommendations.
        cosine_sim (numpy.ndarray): The cosine similarity matrix.

    Returns:
        pandas.Series: A Series of the top 10 most similar movie titles.
    """
    indices = pd.Series(data.index, index=data['title']).drop_duplicates()
    if title not in indices.index: # Use indices.index to check if the title exists
        return "Movie title not found in the dataset."

    idx = indices[title]

    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]

    movie_indices = [i[0] for i in sim_scores]
    return data['title'].iloc[movie_indices]

# Streamlit app interface (initial structure)
st.title('Netflix Movie Recommendation System')
# Out:
# Overwriting app.py

# %% [markdown]
# ## Design streamlit interface
#
# ### Subtask:
# Use Streamlit components (like `st.title`, `st.selectbox`, `st.button`, `st.write`) to create a user interface where the user can select a movie and get recommendations.

# %% [markdown]
# **Reasoning**:
# Add Streamlit components to create the user interface for selecting a movie and displaying recommendations.

# %%
# %%writefile app.py
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import streamlit as st

# Load the data
data = pd.read_csv('/content/sample_data/netflix_titles.csv')

# Data preprocessing
data['director'].fillna('Unknown', inplace=True)
data['cast'].fillna('Unknown', inplace=True)
data['country'].fillna('Unknown', inplace=True)
data['date_added'].fillna('Not Available', inplace=True)
data['rating'].fillna('Unknown', inplace=True)

data.loc[(data['type'] == 'Movie') & (data['duration'].isnull()), 'duration'] = 'Unknown Duration'
data.loc[(data['type'] == 'TV Show') & (data['duration'].isnull()), 'duration'] = 'Unknown Seasons'

data['date_added'] = pd.to_datetime(data['date_added'], errors='coerce')
data['year_added'] = data['date_added'].dt.year
data['month_added'] = data['date_added'].dt.month

data['date_added'].fillna(pd.Timestamp('1900-01-01'), inplace=True)
data['year_added'].fillna(1900, inplace=True)
data['month_added'].fillna(1, inplace=True)

data['year_added'] = data['year_added'].astype(int)
data['month_added'] = data['month_added'].astype(int)

movie_duration = data[data['type'] == 'Movie'].copy()
movie_duration['duration'] = movie_duration['duration'].astype(str).str.replace(' min', '', regex=False)
movie_duration['duration'] = pd.to_numeric(movie_duration['duration'], errors='coerce')
movie_duration['duration'].fillna(movie_duration['duration'].median(), inplace=True)

tv_show_duration = data[data['type'] == 'TV Show'].copy()
tv_show_duration['duration'] = tv_show_duration['duration'].astype(str).str.replace(' Seasons', '', regex=False).str.replace(' Season', '', regex=False)
tv_show_duration['duration'] = pd.to_numeric(tv_show_duration['duration'], errors='coerce')
tv_show_duration['duration'].fillna(tv_show_duration['duration'].median(), inplace=True)

data.loc[data['type'] == 'Movie', 'duration'] = movie_duration['duration']
data.loc[data['type'] == 'TV Show', 'duration'] = tv_show_duration['duration']
data['duration'] = data['duration'].astype(int)


# Content-based filtering code
data['combined_features'] = data['director'] + ' ' + data['cast'] + ' ' + data['listed_in'] + ' ' + data['description']

tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(data['combined_features'])

cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

def get_recommendations(title, cosine_sim=cosine_sim):
    """
    Gets content-based recommendations for a given movie title.

    Args:
        title (str): The title of the movie for which to get recommendations.
        cosine_sim (numpy.ndarray): The cosine similarity matrix.

    Returns:
        pandas.Series or str: A Series of the top 10 most similar movie titles
                                or a string message if the movie is not found.
    """
    indices = pd.Series(data.index, index=data['title']).drop_duplicates()
    if title not in indices.index:
        return "Movie title not found in the dataset."

    idx = indices[title]

    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]

    movie_indices = [i[0] for i in sim_scores]
    return data['title'].iloc[movie_indices]

# Streamlit app interface
st.title('Netflix Movie Recommendation System')

# Selectbox for movie title
selected_movie = st.selectbox('Select a movie:', data['title'])

# Button to trigger recommendations
if st.button('Get Recommendations'):
    recommendations = get_recommendations(selected_movie)

    if isinstance(recommendations, str):
        st.write(recommendations)
    else:
        st.write(f"Recommendations for '{selected_movie}':")
        st.dataframe(recommendations)
# Out:
# Overwriting app.py

# %% [markdown]
# ## Run the streamlit app
#
# ### Subtask:
# Provide instructions on how to run the Streamlit application.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The `streamlit` library was successfully installed using `pip install streamlit`.
# *   An empty Python file named `app.py` was created using `!touch app.py` to house the Streamlit application code.
# *   The necessary libraries (pandas, numpy, sklearn, streamlit) were imported, and the Netflix dataset was loaded and preprocessed within the `app.py` file.
# *   Missing values in key columns ('director', 'cast', 'country', 'date\_added', 'rating', 'duration') were handled using strategies like filling with 'Unknown', 'Not Available', median values, or placeholders.
# *   New features ('year\_added', 'month\_added', 'combined\_features') were created for the recommendation system.
# *   A TF-IDF vectorizer was fitted to the `combined_features`, and the cosine similarity matrix was computed, resulting in a shape of 8807x8807.
# *   The `get_recommendations` function, which uses the cosine similarity matrix to find similar movie titles, was implemented in `app.py`.
# *   Streamlit components, including `st.title`, `st.selectbox` for movie selection, `st.button` to trigger recommendations, and `st.write`/`st.dataframe` to display results or error messages, were added to the `app.py` file to create the user interface.
# *   The final `app.py` file contains the complete code for loading data, preprocessing, implementing the content-based recommendation logic, and designing the Streamlit interface.
#
# ### Insights or Next Steps
#
# *   The current application is a content-based recommendation system. A next step could be to integrate collaborative filtering or other methods to build a hybrid system as initially intended, potentially improving recommendation quality.
# *   To improve the application's performance and user experience, the TF-IDF matrix and cosine similarity matrix could be pre-computed and saved, then loaded by the Streamlit app, rather than recalculating them every time the app runs.

# %% [markdown]
# # Task
# Create a movie recommendation system using hybrid filtering with the dataset "/content/sample_data/netflix_titles.csv", and build a Streamlit application for it.

# %% [markdown]
# ## Pre-compute and save matrices
#
# ### Subtask:
# Modify the notebook to compute the TF-IDF matrix and cosine similarity matrix and save them to files.

# %% [markdown]
# **Reasoning**:
# Compute the TF-IDF matrix and cosine similarity matrix and save them to files using pickle.

# %%
import pickle

# Compute the TF-IDF matrix and cosine similarity matrix (using existing code)
# tfidf_vectorizer = TfidfVectorizer(stop_words='english') # Already defined and fitted
# tfidf_matrix = tfidf_vectorizer.fit_transform(data['combined_features']) # Already computed
# cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix) # Already computed

# Save the TF-IDF matrix
with open('tfidf_matrix.pkl', 'wb') as f:
    pickle.dump(tfidf_matrix, f)

# Save the cosine similarity matrix
with open('cosine_sim.pkl', 'wb') as f:
    pickle.dump(cosine_sim, f)

print("TF-IDF matrix and cosine similarity matrix saved to tfidf_matrix.pkl and cosine_sim.pkl")
# Out:
# TF-IDF matrix and cosine similarity matrix saved to tfidf_matrix.pkl and cosine_sim.pkl

# %% [markdown]
# ## Update streamlit app to load matrices
#
# ### Subtask:
# Modify the `app.py` file to load the pre-computed matrices instead of recalculating them.

# %% [markdown]
# **Reasoning**:
# Modify the app.py file to load the pre-computed matrices instead of recalculating them.

# %%
# %%writefile app.py
import pandas as pd
import numpy as np
import pickle
import streamlit as st

# Load the data
data = pd.read_csv('/content/sample_data/netflix_titles.csv')

# Data preprocessing
data['director'].fillna('Unknown', inplace=True)
data['cast'].fillna('Unknown', inplace=True)
data['country'].fillna('Unknown', inplace=True)
data['date_added'].fillna('Not Available', inplace=True)
data['rating'].fillna('Unknown', inplace=True)

data.loc[(data['type'] == 'Movie') & (data['duration'].isnull()), 'duration'] = 'Unknown Duration'
data.loc[(data['type'] == 'TV Show') & (data['duration'].isnull()), 'duration'] = 'Unknown Seasons'

data['date_added'] = pd.to_datetime(data['date_added'], errors='coerce')
data['year_added'] = data['date_added'].dt.year
data['month_added'] = data['date_added'].dt.month

data['date_added'].fillna(pd.Timestamp('1900-01-01'), inplace=True)
data['year_added'].fillna(1900, inplace=True)
data['month_added'].fillna(1, inplace=True)

data['year_added'] = data['year_added'].astype(int)
data['month_added'] = data['month_added'].astype(int)

movie_duration = data[data['type'] == 'Movie'].copy()
movie_duration['duration'] = movie_duration['duration'].astype(str).str.replace(' min', '', regex=False)
movie_duration['duration'] = pd.to_numeric(movie_duration['duration'], errors='coerce')
movie_duration['duration'].fillna(movie_duration['duration'].median(), inplace=True)

tv_show_duration = data[data['type'] == 'TV Show'].copy()
tv_show_duration['duration'] = tv_show_duration['duration'].astype(str).str.replace(' Seasons', '', regex=False).str.replace(' Season', '', regex=False)
tv_show_duration['duration'] = pd.to_numeric(tv_show_duration['duration'], errors='coerce')
tv_show_duration['duration'].fillna(tv_show_duration['duration'].median(), inplace=True)

data.loc[data['type'] == 'Movie', 'duration'] = movie_duration['duration']
data.loc[data['type'] == 'TV Show', 'duration'] = tv_show_duration['duration']
data['duration'] = data['duration'].astype(int)

# Load pre-computed matrices
try:
    with open('/content/tfidf_matrix.pkl', 'rb') as f:
        tfidf_matrix = pickle.load(f)
    with open('/content/cosine_sim.pkl', 'rb') as f:
        cosine_sim = pickle.load(f)
except FileNotFoundError:
    st.error("Pre-computed matrices not found. Please run the notebook cells to generate them.")
    st.stop() # Stop the app if files are not found


def get_recommendations(title, cosine_sim=cosine_sim):
    """
    Gets content-based recommendations for a given movie title.

    Args:
        title (str): The title of the movie for which to get recommendations.
        cosine_sim (numpy.ndarray): The cosine similarity matrix.

    Returns:
        pandas.Series or str: A Series of the top 10 most similar movie titles
                                or a string message if the movie is not found.
    """
    indices = pd.Series(data.index, index=data['title']).drop_duplicates()
    if title not in indices.index:
        return "Movie title not found in the dataset."

    idx = indices[title]

    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]

    movie_indices = [i[0] for i in sim_scores]
    return data['title'].iloc[movie_indices]

# Streamlit app interface
st.title('Netflix Movie Recommendation System')

# Selectbox for movie title
selected_movie = st.selectbox('Select a movie:', data['title'])

# Button to trigger recommendations
if st.button('Get Recommendations'):
    recommendations = get_recommendations(selected_movie)

    if isinstance(recommendations, str):
        st.write(recommendations)
    else:
        st.write(f"Recommendations for '{selected_movie}':")
        st.dataframe(recommendations)
# Out:
# Overwriting app.py

# %% [markdown]
# ## Run the optimized streamlit app
#
# ### Subtask:
# Run the updated Streamlit application to see the improved startup time.

# %% [markdown]
# **Reasoning**:
# Run the Streamlit application with localtunnel to make it accessible.

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ⠙
# ...
#
# ⠹⠸⠼⠴
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.229.165.4:8501
#
# ⠦⠧⠇⠏⠋⠙⠹⠸your url is: https://silver-papayas-marry.loca.lt
# /content/app.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['director'].fillna('Unknown', inplace=True)
# ...

# %%
# %%writefile requirements.txt
# streamlit
# pandas
# numpy
# scikit-learn
# Out:
# Writing requirements.txt
